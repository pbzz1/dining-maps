# %% [markdown]
# # 데이터 확인

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lotteria = pd.read_csv('../data/lotteria.csv')
mcdonalds = pd.read_csv('../data/mcdonalds.csv')
momstouch = pd.read_csv('../data/momstouch.csv')
salady = pd.read_csv('../data/salady.csv')
subway = pd.read_csv('../data/subway.csv')

# %%
lotteria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant       100 non-null    object
#  1   menu_name        100 non-null    object
#  2   menu_category    100 non-null    object
#  3   weight_g         100 non-null    float64
#  4   calorie_kcal     100 non-null    int64
#  5   protein_g        100 non-null    int64
#  6   sodium_mg        100 non-null    int64
#  7   sugar_g          100 non-null    int64
#  8   saturated_fat_g  100 non-null    float64
#  9   caffeine_mg      9 non-null      float64
#  10  allergy_info     100 non-null    object
#  11  origin_info      48 non-null     object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 9.5+ KB

# %%
mcdonalds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant       116 non-null    object
#  1   menu_name        116 non-null    object
#  2   menu_group       116 non-null    object
#  3   price_krw        0 non-null      float64
#  4   weight_g         116 non-null    int64
#  5   calorie_kcal     116 non-null    int64
#  6   protein_g        116 non-null    float64
#  7   sugar_g          116 non-null    int64
#  8   saturated_fat_g  116 non-null    float64
#  9   sodium_mg        116 non-null    int64
#  10  caffeine_mg      44 non-null     float64
#  11  allergy_info     110 non-null    object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 11.0+ KB

# %%
momstouch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   restaurant              34 non-null     object
#  1   menu_name               34 non-null     object
#  2   menu_category           34 non-null     object
#  3   weight_g                34 non-null     int64
#  4   calorie_kcal            34 non-null     int64
#  5   protein_g               34 non-null     int64
#  6   sodium_mg               34 non-null     int64
#  7   sugar_g                 34 non-null     int64
#  8   saturated_fat_g         34 non-null     float64
#  9   set_calorie_range_kcal  34 non-null     object
#  10  data_source             34 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 3.1+ KB

# %%
salady.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant       42 non-null     object
#  1   menu_name        42 non-null     object
#  2   menu_category    42 non-null     object
#  3   calorie_kcal     42 non-null     float64
#  4   carb_g           42 non-null     float64
#  5   sugar_g          42 non-null     float64
#  6   protein_g        42 non-null     float64
#  7   fat_g            42 non-null     float64
#  8   saturated_fat_g  42 non-null     float64
#  9   sodium_mg        42 non-null     float64
#  10  menu_item_idx    42 non-null     int64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 3.7+ KB

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   restaurant       24 non-null     object
#  1   menu_name        24 non-null     object
#  2   menu_name_en     0 non-null      float64
#  3   menu_category    24 non-null     object
#  4   weight_g         24 non-null     object
#  5   calorie_kcal     24 non-null     int64
#  6   protein_g        24 non-null     float64
#  7   sugar_g          24 non-null     float64
#  8   saturated_fat_g  24 non-null     float64
#  9   sodium_mg        24 non-null     int64
#  10  menu_item_idx    24 non-null     int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 2.2+ KB

# %% [markdown]
# ## 롯데리아

# %%
lotteria
# Out:
#    restaurant        menu_name  menu_category  weight_g  calorie_kcal  \
# 0        롯데리아          리아 두툼새우           버거메뉴     263.0           549
# 1        롯데리아  리아 두툼새우 스파이시토마토           버거메뉴     263.0           516
# 2        롯데리아          한우불고기버거           버거메뉴     263.0           572
# 3        롯데리아        더블한우불고기버거           버거메뉴     352.0           802
# 4        롯데리아           리아 불고기           버거메뉴     192.0           462
# ..        ...              ...            ...       ...           ...
# 95       롯데리아        야채라이스 불고기           리아모닝     221.0           520
# 96       롯데리아         야채라이스 새우           리아모닝     205.0           434
# 97       롯데리아           베이컨에그번           리아모닝     159.0           386
# 98       롯데리아           에그샐러드번           리아모닝     180.0           446
# 99       롯데리아        새우 + 치킨버거  쿠팡이츠 '하나만' 메뉴     321.0           825
#
#     protein_g  sodium_mg  sugar_g  saturated_fat_g  caffeine_mg  \
# ...

# %%
sns.pairplot(lotteria, hue='calorie_kcal')

# %%
sns.boxplot(y='calorie_kcal', data=lotteria, orient='h')
# Out:
# C:\Users\taehu\AppData\Roaming\Python\Python314\site-packages\seaborn\_base.py:1601: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# <Axes: ylabel='calorie_kcal'>

# %%
lotteria.describe()
# Out:
#         weight_g  calorie_kcal   protein_g    sodium_mg     sugar_g  \
# count  100.00000    100.000000  100.000000   100.000000  100.000000
# mean   229.34100    390.910000   16.390000   611.800000   13.870000
# std    158.39106    333.940208   24.533998   622.270687   20.942275
# min      2.60000      0.000000    0.000000     0.000000    0.000000
# 25%    113.50000    149.500000    0.000000   120.000000    1.000000
# 50%    205.00000    351.500000   11.000000   495.000000    6.000000
# 75%    305.25000    572.500000   23.000000   970.000000   13.250000
# max    584.00000   1812.000000  197.000000  3109.000000   99.000000
#
#        saturated_fat_g  caffeine_mg
# count        100.00000     9.000000
# mean           5.56300    47.444444
# std            6.07014    22.738245
# min            0.00000    14.000000
# 25%            0.37500    29.000000
# 50%            3.95000    48.000000
# 75%            7.00000    52.000000
# max           24.00000    88.000000

# %%
lotteria.sort_values('calorie_kcal', ascending=False).head(10)
# Out:
#    restaurant                 menu_name  menu_category  weight_g  \
# 43       롯데리아  후라이드 순살치킨 N (L) (소스 미포함)           치킨메뉴     584.0
# 41       롯데리아    후라이드 순살치킨 (L) (소스 미포함)           치킨메뉴     584.0
# 39       롯데리아          순살치킨 풀팩 (소스 미포함)           치킨메뉴     487.0
# 42       롯데리아  후라이드 순살치킨 N (R) (소스 미포함)           치킨메뉴     292.0
# 37       롯데리아    치킨다리 하프팩(포테이토) (소스미포함)           치킨메뉴     426.0
# 40       롯데리아    후라이드 순살치킨 (R) (소스 미포함)           치킨메뉴     292.0
# 99       롯데리아                 새우 + 치킨버거  쿠팡이츠 '하나만' 메뉴     321.0
# 3        롯데리아                 더블한우불고기버거           버거메뉴     352.0
# 27       롯데리아               하와이안 모짜렐라버거           버거메뉴     290.0
# 23       롯데리아          나폴리 모짜렐라버거 발사믹바질           버거메뉴     250.0
#
#     calorie_kcal  protein_g  sodium_mg  sugar_g  saturated_fat_g  caffeine_mg  \
# 43          1812         97       3109        1             21.0          NaN
# 41          1725        197       3040        1             19.0          NaN
# ...

# %% [markdown]
# 이상하게 칼로리가 평균 값을 넘고 boxplot에서도 이상치로 탐지되는 데이터가 보여 확인해보니 버거 뿐만 아니라 치킨도 같이 집계되며 '후라이드 순살치킨 N' 품목이 이상치로 탐지됨 따로 분류하거나 일단 제거하는 것이 좋아보임

# %%
sns.pairplot(salady, hue='calorie_kcal')

# %%
sns.boxplot(y='calorie_kcal', data=salady, orient='h')
# Out:
# C:\Users\taehu\AppData\Roaming\Python\Python314\site-packages\seaborn\_base.py:1601: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# <Axes: ylabel='calorie_kcal'>
