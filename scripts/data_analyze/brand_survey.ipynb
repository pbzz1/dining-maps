# %%
import pandas as pd
df = pd.read_csv('C:/Users/taehu/Desktop/취업준비/projects/dining_maps/data/brand_survey.csv',)
df
# Out:
#       brand category    status nutrition nutrition_format  \
# 0      롯데리아       버거   adopted         Y      server_html
# 1      맘스터치       버거   adopted   partial            image
# 2      맥도날드       버거   adopted         Y         json_api
# 3      서브웨이     샌드위치   adopted         Y      server_html
# 4       샐러디      샐러드   adopted         Y      server_html
# 5    배스킨라빈스      디저트   adopted         Y      server_html
# 6       버거킹       버거   adopted         Y         json_api
# 7     포케올데이      샐러드   adopted         Y      server_html
# 8       BHC       치킨   adopted         Y         json_api
# 9      교촌치킨       치킨   adopted         Y         json_api
# 10      빽다방       커피   adopted         Y      server_html
# 11     스타벅스       커피   adopted         Y         json_api
# 12      이디야       커피   adopted         Y      server_html
# 13      커피빈       커피   adopted         Y      server_html
# 14      할리스       커피   adopted         Y      server_html
# ...
